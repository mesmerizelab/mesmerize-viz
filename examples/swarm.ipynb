# %%
import pandas as pd
import numpy as np
from uuid import uuid4
from viz.dashboards import Swarm
from bokeh.io import show, output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
df['uuid'] = [str(uuid4()) for i in range(df.index.size)]
df['random_data'] = [np.random.randint(0, 100) for i in range(df.index.size)]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  \
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
#                                    uuid  random_data
# 0  2aacfcc8-2209-40d9-8e58-c6ed7f6179e9           68
# 1  dc6e8412-3328-41a9-8a7c-f958ca604a56           43
# 2  4eb63854-14f6-4d98-839c-6a6286f4e2b1           12
# 3  f2996f39-2d15-4460-9973-c307a0a82f93           82
# 4  132353f1-7b8f-43be-8652-e0bb86bc23fa           98

# %%
dashboard = Swarm(
    dataframe=df,
    data_column='sepal_length',
    groupby_column='species',
    tooltip_columns=df.columns,
    source_columns=df.columns
)
# Out:
# WEBPLOT INIT
# [<viz.core.signal.BokehCallbackSignal object at 0x7f34d6604be0>]

# %%
# when ``sig_point_selected`` is triggered it will update the text entry
dashboard.sig_point_selected.connect_data(dashboard.update_table_widget, 'uuid')

# %%
show(dashboard.start_app, notebook_url="http://localhost:8001")
# Out:
# <script id="1040">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:39065/autoload.js?bokeh-autoload-element=1040&bokeh-absolute-url=http://localhost:39065&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# starting app
# VAL IN SIGNAL: [106]
# 17cd4cea-956c-417f-80ae-46a273407436
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 106           4.9          2.5           4.5          1.7  virginica
#
#                                      uuid  random_data
# 106  17cd4cea-956c-417f-80ae-46a273407436           43
# VAL IN SIGNAL: [89]
# fa5fd32b-7907-4e93-941b-5008c5d256e7
#     sepal_length  sepal_width  petal_length  petal_width     species  \
# 89           5.5          2.5           4.0          1.3  versicolor
#
#                                     uuid  random_data
# 89  fa5fd32b-7907-4e93-941b-5008c5d256e7           19
# VAL IN SIGNAL: [82]
# 92498588-486f-4b00-8eab-9bd0e46a1ced
#     sepal_length  sepal_width  petal_length  petal_width     species  \
# 82           5.8          2.7           3.9          1.2  versicolor
#
#                                     uuid  random_data
# 82  92498588-486f-4b00-8eab-9bd0e46a1ced           60
# VAL IN SIGNAL: [50]
# 27fd268e-f219-4938-9e33-eab1f55dff59
#     sepal_length  sepal_width  petal_length  petal_width     species  \
# 50           7.0          3.2           4.7          1.4  versicolor
#
#                                     uuid  random_data
# 50  27fd268e-f219-4938-9e33-eab1f55dff59           69
